# %% [markdown]
# # CARA MEMBUAT BAR PLOT / BAR CHART ##

# %% [markdown]
# ## Import Modules ##

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.20.3

# %% [markdown]
# # Simple Bar Plot ###

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.bar(kategori, data)
plt.grid()

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %% [markdown]
# ## Pengaturan Grid Dan Color ##

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.bar(kategori, 
        data,
        color='red',
        alpha=0.25)

plt.grid(linestyle='--',
        linewidth=2,
        axis='y', # pilihan : x, y, both
        alpha=0.50)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %%
plt.bar(kategori, 
        data,
        color='red',
        alpha=0.75) # semakin besar warnanya semakin pekat

plt.grid(linestyle='--',
        linewidth=2,
        axis='y', # pilihan : x, y, both
        alpha=0.50)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %%
plt.bar(kategori, 
        data,
        color='red',
        alpha=0.75) # semakin besar warnanya semakin pekat

plt.grid(linestyle='--',
        linewidth=2,
        axis='x', # pilihan : x, y, both
        alpha=0.50)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %%
plt.bar(kategori, 
        data,
        color='red',
        alpha=0.75) # semakin besar warnanya semakin pekat

plt.grid(linestyle='--',
        linewidth=2,
        axis='x', # pilihan : x, y, both
        alpha=0.25) # semakin kecil semakin pudar garis axisnya

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')
# Out:
# Text(0.5, 1.0, 'Contoh Bar Plot')

# %% [markdown]
# ### Horisontal Bar Plot ###

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.barh(kategori, data)
# plt.barh(kategori[::-1], data[::-1])

plt.grid(linestyle='--',
        linewidth=1,
        axis='x', # pilihan : x, y, both
        alpha=0.75)

plt.xlabel('Jumlah')
plt.ylabel('Kategori')
plt.title('Contoh Horisontal Bar Plot')

plt.show()

# %%
#plt.barh(kategori, data)
plt.barh(kategori[::-1], data[::-1]) #cara membalik urutan

plt.grid(linestyle='--',
        linewidth=1,
        axis='x', # pilihan : x, y, both
        alpha=0.75)

plt.xlabel('Jumlah')
plt.ylabel('Kategori')
plt.title('Contoh Horisontal Bar Plot')

plt.show()

# %% [markdown]
# ### Stacked Bar Plot ###

# %%
data1 = [25, 85, 75, 40, 60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.bar(kategori, data1, label='Data 1')
#plt.bar(kategori, data2, label='Data 2')
plt.bar(kategori, data2, label='Data 2', bottom=data1) #cara membalik urutan

plt.legend()

plt.grid(linestyle='--',
        linewidth=1,
        axis='y', # pilihan : x, y, both
        alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %%
plt.bar(kategori, data1, label='Data 1', bottom=data2) # bottom untuk membalik data 1 dan 2
#plt.bar(kategori, data2, label='Data 2')
plt.bar(kategori, data2, label='Data 2') #cara membalik urutan

plt.legend()

plt.grid(linestyle='--',
        linewidth=1,
        axis='y', # pilihan : x, y, both
        alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %%
plt.bar(kategori, data1, label='Data 1')
plt.bar(kategori, data2, label='Data 2') 
# plt.bar(kategori, data2, label='Data 2', bottom=data1)

plt.legend()

plt.grid(linestyle='--',
        linewidth=1,
        axis='y', # pilihan : x, y, both
        alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %% [raw]
# Terjadi penimpaan plotting di atas

# %%
plt.bar(kategori, data2, label='Data 2') 
plt.bar(kategori, data1, label='Data 1')
# plt.bar(kategori, data2, label='Data 2', bottom=data1)

plt.legend()

plt.grid(linestyle='--',
        linewidth=1,
        axis='y', # pilihan : x, y, both
        alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %% [raw]
# kalau di balik data 2 terlebih dahulu yang akan di jalankan jadi seperti di atas

# %%
plt.bar(kategori, data1, label='Data x') #berubah nama
#plt.bar(kategori, data2, label='Data 2') 
plt.bar(kategori, data2, label='Data 2', bottom=data1)

plt.legend()

plt.grid(linestyle='--',
        linewidth=1,
        axis='y', # pilihan : x, y, both
        alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %% [markdown]
# # Group Bar Plot ##

# %%
data1 = [25, 85, 75, 40, 60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

x = np.arange(len(kategori))
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
width = 0.35 # lebar jarak bar 

plt.bar(x-width/2, data1, width, label='Data 1')
plt.bar(x+width/2, data2, width, label='Data 2')

plt.xticks(x, kategori)

plt.grid(linestyle='--',
        linewidth=1,
        axis='y',
        alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Grouped Bar Plot')

plt.show()

# %% [raw]
# Bedanya Group Bar Plot dengan Stack Bar Plot dimana dua data set bar plot akan berbeda dengan lainnya tidak menumpuk

# %%
data1 = [25, 85, 75, 40, 60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

x = np.arange(len(kategori))
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
width = 0.5  # lebar jarak bar 

plt.bar(x-width/2, data1, width, label='Data 1')
plt.bar(x+width/2, data2, width, label='Data 2')

plt.xticks(x, kategori)

plt.grid(linestyle='--',
        linewidth=1, #lebar dari setiap barcode
        axis='y', 
        alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Grouped Bar Plot')

plt.show()

# %%
data1 = [25, 85, 75, 40, 60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

x = np.arange(len(kategori))
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
width = 0.35  # lebar jarak bar 

plt.bar(x-width/2, data1, width, label='Data 1')
plt.bar(x+width/2, data2, width, label='Data 2')

# plt.xticks(x, kategori) untuk menampilkan keterangan data warna dan kategori

plt.grid(linestyle='--',
        linewidth=1, #lebar dari setiap barcode
        axis='y', 
        alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Grouped Bar Plot')

plt.show()

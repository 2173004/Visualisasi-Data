# %% [markdown]
# # CARA MEMBUAT ANIMASI PADA MATPLOTLIB

# %% [markdown]
# ### Import Modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.20.3

# %% [markdown]
# ### Review Figure

# %%
fig = plt.figure()
# plt.xlim((0, 4))
# plt.ylim((-2, 2))

# print(plt.plot([]))

# %%
fig = plt.figure()
plt.xlim((0, 4)) #untuk menentukan baris atas dan bawa sumbu x
plt.ylim((-2, 2)) #untuk menentukan baris atas dan bawa sumbu y

# print(plt.plot([]))
# Out:
# (-2.0, 2.0)

# %%
fig = plt.figure()
plt.xlim((0, 8)) #untuk menentukan baris atas dan bawa sumbu x
plt.ylim((-, 2)) #untuk menentukan baris atas dan bawa sumbu y

# print(plt.plot([]))
# Out:
# (-4.0, 2.0)

# %%
fig = plt.figure()
plt.xlim((0, 8)) #untuk menentukan baris atas dan bawa sumbu x
plt.ylim((-4, 2)) #untuk menentukan baris atas dan bawa sumbu y

print(plt.plot([]))

# %% [markdown]
# ### Animasi Pada Matplotlib ###

# %%
fig = plt.figure()
plt.xlim((0, 4))
plt.ylim((-2, 2))

line = plt.plot([])[0]


def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,


anim = FuncAnimation(fig, animate, frames=200, interval=5)


video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)

plt.close()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
fig = plt.figure()
plt.xlim((0, 4))
plt.ylim((-2, 2))

line = plt.plot([])[0]


def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,


anim = FuncAnimation(fig, animate, frames=200, interval=5)


video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)

# plt.close()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
fig = plt.figure()
plt.xlim((0, 4))
plt.ylim((-2, 2))

line = plt.plot([])[0]


def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,


anim = FuncAnimation(fig, animate, frames=25, interval=5)


video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)

plt.close()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [raw]
# 2173004 Velinda Novelia Candra

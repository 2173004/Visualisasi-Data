# %% [markdown]
# # MEMBUAT 3D AREA PLOTTING / 3D AREA CHART ###

# %% [markdown]
# ### Import Modules ###

# %%
#%matplotlib inline
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.20.3

# %% [markdown]
# ### Sample Dataset ###

# %%
n = np.linspace(-3.0, 3.0, 100)

x, y = np.meshgrid(n, n)
z = np.sqrt(x**2 + y**2)

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# ### 3D WireFrame ###

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_wireframe(x, y, z, color='orange')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Contoh 3D Wireframe')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="518.333312736618">

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_wireframe(x, y, z, color='green')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Contoh 3D Wireframe')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="518.333312736618">

# %% [markdown]
# ### 3D Surface Plot ###

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z, color='orange')
# ax.plot_surface(x, y, z, cmap='viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Contoh 3D Surface Plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="518.333312736618">

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z, color='pink')
# ax.plot_surface(x, y, z, cmap='viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Contoh 3D Surface Plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="518.333312736618">

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

#ax.plot_surface(x, y, z, color='orange')
ax.plot_surface(x, y, z, cmap='viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Contoh 3D Surface Plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="518.333312736618">

# %% [raw]
# 2173004 Velinda Novelia Candra
